# %%
import numpy as np
import pandas as pd

# %%
dscurahhujan = pd.read_csv("./laporan_iklim_harian_2016-2019.csv")
dscurahhujan.head()
# Out:
#     tanggal  tempMin  tempMax  tempRata  kelembaban  curahHujan  \
# 0  1/1/2016     26.0      NaN      29.3        86.0        17.7
# 1  1/3/2016     26.0     32.7      28.9        89.0        15.5
# 2  1/4/2016     26.0     32.7      27.7        90.0         8.5
# 3  1/5/2016     26.0     32.4      28.0        89.0         3.8
# 4  1/6/2016     24.0     32.3      29.0        87.0        17.2
#
#    sinarMatahari  kecepatanAngin  arahAngin  anginRata arahAnginBanyak
# 0            4.1             3.0      220.0        1.0              N
# 1            3.2             2.0      340.0        0.0              N
# 2            5.2             3.0      200.0        1.0              N
# 3            2.7             3.0      100.0        1.0              N
# 4            1.5             4.0      120.0        2.0              N

# %%
filterX = ["tempRata", "kelembaban", "kecepatanAngin"]
datacurahX = dscurahhujan[filterX]
datacurahX
# Out:
#       tempRata  kelembaban  kecepatanAngin
# 0         29.3        86.0             3.0
# 1         28.9        89.0             2.0
# 2         27.7        90.0             3.0
# 3         28.0        89.0             3.0
# 4         29.0        87.0             4.0
# ...        ...         ...             ...
# 1068      28.1        83.0             4.0
# 1069      29.0        80.0             5.0
# 1070      30.3        78.0             4.0
# 1071      28.7        84.0             3.0
# 1072      26.6        91.0             3.0
#
# [1073 rows x 3 columns]

# %%
filterY = ["curahHujan"]
datacurahY = dscurahhujan[filterY]
datacurahY
# Out:
#       curahHujan
# 0           17.7
# 1           15.5
# 2            8.5
# 3            3.8
# 4           17.2
# ...          ...
# 1068         0.0
# 1069         0.9
# 1070         0.5
# 1071         0.0
# 1072        13.7
#
# [1073 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
figure(num=None, figsize=(30, 10), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(dscurahhujan.tanggal, dscurahhujan.curahHujan)
plt.title("data scatter curah hujan aktual")
plt.ylabel("curah hujan (m3)")
plt.xlabel("tanggal")
plt.show()
